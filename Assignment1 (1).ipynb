# %% [markdown]
# 1. Write a Python program to calculate the length of a string without using library function

# %%
a = "sindhu"
length = 0
for i in a:
  length+=1
print(length)
# Out:
# 6

# %% [markdown]
# 2. Write a Python program to count the number of characters (character frequency) in a string             Sample String : google.com'
# Expected Result : {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %%
s = list(input("Enter a string: "))
unique = []
for i in s:
  if  i not in unique:
    unique.append(i)
print(unique)
dictionary = {}
for q in unique:
  dictionary[q] = s.count(q)
print(dictionary)
# Out:
# Enter a string: google.com
# ['g', 'o', 'l', 'e', '.', 'c', 'm']
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %% [markdown]
# 3. Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. If the string length is less than 2, return "empty string"                                                                 Sample String : 'w3resource'
# Expected Result : 'w3ce'
# Sample String : 'w3'
# Expected Result : 'w3w3'
# Sample String : ' w'
# Expected Result : Empty String

# %%
string = list("w3resource")
if len(string) == 2:
  print("".join(string)+"".join(string))
elif len(string) < 2 :
  print("enpty string")
else:
  for i in range(0,len(string)):
    if i == 0 or i == 1 or i == (len(string)-1) or i == (len(string)-2):
      print(string[i],end="")
# Out:
# w3ce

# %% [markdown]
# 4. Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', except the first char itself.
# Sample String : 'restart'
# Expected Result : 'resta$t'

# %%
string = "restart"
s = list(string)
a = s[0]
for i in range(0,len(s)):
  if i !=0:
    if s[i] is a:
      s[i] = "$"
print("".join(s))
# Out:
# resta$t

# %% [markdown]
# 5. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
# Sample String : 'abc', 'xyz'
# Expected Result : 'xyc abz'

# %%
s1 =list("abc")
s2 =list("xyz")
s3 = s1.copy()
s1[0]=s2[0]
s1[1] = s2[1]
s2[0]=s3[0]
s2[1] =s3[1]
print("".join(s1)+" "+"".join(s2))
# Out:
# xyc abz

# %% [markdown]
# 6. Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
# Sample String : 'abc'
# Expected Result : 'abcing'
# Sample String : 'string'
# Expected Result : 'stringly'

# %%
s = "string"
length = len(s)
if length >2:
  if s[-3: :1] == "ing":
    s += "ly"
  else:
    s += "ing"
print(s)
# Out:
# stringly
